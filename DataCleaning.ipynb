# %% [markdown]
# <a href="https://colab.research.google.com/github/eemanishimwe/exercise/blob/main/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/gender_desparties_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   id  gender   age marital_status education_level  \
# 0           0  NaN    Male  57.0         Single         Primary
# 1           1  2.0  Female  24.0         Single       Secondary
# 2           2  3.0    Male  49.0         Single       Secondary
# 3           3  4.0    Male  36.0        Married             NaN
# 4           4  5.0    Male  23.0        Married       Secondary
#
#    years_of_experience    region owns_motorcycle  income_per_month  ...  \
# 0                 26.0   Eastern              No          105008.0  ...
# 1                  0.0    Kigali              No          149370.0  ...
# 2                  6.0   Western              No               NaN  ...
# 3                 21.0  Southern             Yes          134455.0  ...
# 4                 29.0   Eastern             Yes          156930.0  ...
#
#    days_worked_per_week  accidents_last_year  health_issues  \
# 0                   6.0                  1.0             No
# ...

# %%
df.drop(columns=["health_issues"], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   id  gender   age marital_status education_level  \
# 0           0  NaN    Male  57.0         Single         Primary
# 1           1  2.0  Female  24.0         Single       Secondary
# 2           2  3.0    Male  49.0         Single       Secondary
# 3           3  4.0    Male  36.0        Married             NaN
# 4           4  5.0    Male  23.0        Married       Secondary
#
#    years_of_experience    region owns_motorcycle  income_per_month  ...  \
# 0                 26.0   Eastern              No          105008.0  ...
# 1                  0.0    Kigali              No          149370.0  ...
# 2                  6.0   Western              No               NaN  ...
# 3                 21.0  Southern             Yes          134455.0  ...
# 4                 29.0   Eastern             Yes          156930.0  ...
#
#    days_worked_per_week  accidents_last_year  membership_in_union  \
# 0                   6.0                  1.0                  Yes
# ...

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0      id  gender   age marital_status education_level  \
# 0              0     NaN    Male  57.0         Single         Primary
# 1              1     2.0  Female  24.0         Single       Secondary
# 2              2     3.0    Male  49.0         Single       Secondary
# 3              3     4.0    Male  36.0        Married             NaN
# 4              4     5.0    Male  23.0        Married       Secondary
# ...          ...     ...     ...   ...            ...             ...
# 4995        4995  4996.0  Female  18.0        Married             NaN
# 4996        4996  4997.0    Male  54.0        Married       Secondary
# 4997        4997  4998.0    Male  30.0         Single       Secondary
# 4998        4998  4999.0    Male  38.0        Married         Primary
# 4999        4999  5000.0    Male  26.0        Married       Secondary
#
#       years_of_experience    region owns_motorcycle  income_per_month  \
# ...

# %%
df["total_income"] = df["income_per_month"]*2

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'gender', 'age', 'marital_status',
#        'education_level', 'years_of_experience', 'region', 'owns_motorcycle',
#        'income_per_month', 'hours_worked_per_day', 'days_worked_per_week',
#        'accidents_last_year', 'membership_in_union', 'access_to_financing',
#        'access_to_training', 'customer_preference',
#        'police_harassment_reports', 'job_satisfaction', 'future_job_security',
#        'total_income'],
#       dtype='object')

# %%
df["income_per_month"].head()
# Out:
# 0    105008.0
# 1    149370.0
# 2         NaN
# 3    134455.0
# 4    156930.0
# Name: income_per_month, dtype: float64

# %%
df.describe()
# Out:
#         Unnamed: 0           id          age  years_of_experience  \
# count  5000.000000  4885.000000  4885.000000          4885.000000
# mean   2499.500000  2497.143705    38.334493            14.430502
# std    1443.520003  1442.727870    12.041811             8.625734
# min       0.000000     2.000000    18.000000             0.000000
# 25%    1249.750000  1246.000000    28.000000             7.000000
# 50%    2499.500000  2497.000000    38.000000            14.000000
# 75%    3749.250000  3746.000000    49.000000            22.000000
# max    4999.000000  5000.000000    59.000000            29.000000
#
#        income_per_month  hours_worked_per_day  days_worked_per_week  \
# count       4885.000000           4885.000000           4885.000000
# mean      149705.367247              9.058342              4.991607
# std        29913.210638              2.580655              0.817080
# min        46399.000000              5.000000              4.000000
# ...

# %%
df[df["education_level"] == "Primary"]
# Out:
#       Unnamed: 0      id  gender   age marital_status education_level  \
# 0              0     NaN    Male  57.0         Single         Primary
# 7              7     8.0  Female  54.0                        Primary
# 13            13    14.0    Male  22.0         Single         Primary
# 14            14     NaN    Male  40.0        Married         Primary
# 15            15    16.0    Male  54.0        Married         Primary
# ...          ...     ...     ...   ...            ...             ...
# 4987        4987  4988.0    Male  47.0         Single         Primary
# 4988        4988  4989.0    Male  38.0       Divorced         Primary
# 4992        4992  4993.0    Male  43.0            NaN         Primary
# 4994        4994  4995.0    Male  38.0                        Primary
# 4998        4998  4999.0    Male  38.0        Married         Primary
#
#       years_of_experience    region owns_motorcycle  income_per_month  ...  \
# ...

# %%
df
# Out:
#       Unnamed: 0      id  gender   age marital_status education_level  \
# 0              0     NaN    Male  57.0         Single         Primary
# 1              1     2.0  Female  24.0         Single       Secondary
# 2              2     3.0    Male  49.0         Single       Secondary
# 3              3     4.0    Male  36.0        Married             NaN
# 4              4     5.0    Male  23.0        Married       Secondary
# ...          ...     ...     ...   ...            ...             ...
# 4995        4995  4996.0  Female  18.0        Married             NaN
# 4996        4996  4997.0    Male  54.0        Married       Secondary
# 4997        4997  4998.0    Male  30.0         Single       Secondary
# 4998        4998  4999.0    Male  38.0        Married         Primary
# 4999        4999  5000.0    Male  26.0        Married       Secondary
#
#       years_of_experience    region owns_motorcycle  income_per_month  ...  \
# ...

# %%
df["membership_in_union"].value_counts()
# Out:
# membership_in_union
# No     2431
# Yes    1468
#         986
# Name: count, dtype: int64

# %%
df["membership_in_union"] = df["membership_in_union"].fillna("yes")

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
sn.barplot(df["gender"],color="green")
# Out:
# <Axes: ylabel='gender'>

# %%
sn.histplot(df["education_level"])
plt.title("ed-level")
# Out:
# Text(0.5, 1.0, 'ed-level')

# %%
sn.lineplot(x="age",y="income_per_month", data=df)
# Out:
# <Axes: xlabel='age', ylabel='income_per_month'>

# %%
sn.scatterplot(df["age"])
# Out:
# <Axes: ylabel='age'>

# %%
sn.pairplot(df)

# %%
sn.heatmap(pd.crosstab(df["gender"], df["education_level"]))
# Out:
# <Axes: xlabel='education_level', ylabel='gender'>
